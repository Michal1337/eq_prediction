# %%
import numpy as np
import tensorflow as tf
import tqdm
import os
# Out:
# 2023-11-21 17:01:49.208398: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-21 17:01:49.208596: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-21 17:01:49.212552: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-21 17:01:49.570438: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-21 17:01:51.957283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
input_directory = '../data/npys/'
output_directory = '../data/datasets/'

# %%
def data_generator(input_directory, idx, split):
    x = np.load(os.path.join(input_directory, f"x_{split}_{idx}.npy"))
    x_reg = np.load(os.path.join(input_directory, f"x_{split}_region{idx}.npy"))
    y = np.load(os.path.join(input_directory, f"y_{split}_{idx}.npy"))
    for i in range(x.shape[0]):
        yield x[i], x_reg[i], y[i]

# %%
x_shape = np.load(os.path.join(input_directory, f"x_train_0.npy")).shape[1:]
x_reg_shape = np.load(os.path.join(input_directory, f"x_train_region0.npy")).shape[1:]
y_shape = np.load(os.path.join(input_directory, f"y_train_0.npy")).shape[1:]
for idx in tqdm.tqdm(range(1378)):
    for split in ['train', 'val', 'test']:
        dataset = tf.data.Dataset.from_generator(
            lambda: data_generator(input_directory, idx, split),
            output_signature=(
                tf.TensorSpec(shape=x_shape, dtype=tf.float32),
                tf.TensorSpec(shape=x_reg_shape, dtype=tf.float32),
                tf.TensorSpec(shape=y_shape, dtype=tf.float32),
            )
        )
        dataset.save(os.path.join(output_directory, f"{split}_{idx}"))
# Out:
#   0%|          | 0/1378 [00:00<?, ?it/s]2023-11-21 17:01:56.730649: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:57.076005: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:57.076095: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:57.085313: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:57.085399: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:57.085443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:59.249254: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:59.249643: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:59.249681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-11-21 17:01:59.249936: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-11-21 17:01:59.250997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3886 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
# 100%|██████████| 1378/1378 [37:48<00:00,  1.65s/it]
